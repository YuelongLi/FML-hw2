# %% [markdown]
# 1. Download and install the libsvm software library from:
#         https://www.csie.ntu.edu.tw/~cjlin/libsvm
# and briefly consult the documentation to become more familiar with the tools.

# %%
# imports
from libsvm.svmutil import *

# %% [markdown]
# 2. Download the Abalone data set: http://archive.ics.uci.edu/ml/datasets/Abalone
# Use the libsvm scaling tool to scale the features of all the data. Use the first 3133 examples for
# training, the last 1044 for testing. The scaling parameters should be computed only on the training
# data and then applied to the test data.

# %%
[Y,X]=svm_read_problem("abalone.data")

# %%
X_train = X[0:3134]
Y_train = Y[0:3134]
X_test = X[3134:]
Y_test = Y[3134:]

# %%
l = -1
r = 1

# %%
scale_param = {}
for i in range(1,9):
    scale_param[i] = [X_train[0][i], X_train[0][i]]
for x in X_train:
    for i in range(1,9):
        if(x[i]<scale_param[i][0]):
            scale_param[i][0] = x[i]
        
        if(x[i]>scale_param[i][1]):
            scale_param[i][1] = x[i]
scale_param
# Out:
# {1: [1.0, 3.0],
#  2: [0.075, 0.815],
#  3: [0.055, 0.65],
#  4: [0.0, 1.13],
#  5: [0.002, 2.8255],
#  6: [0.001, 1.488],
#  7: [0.0005, 0.76],
#  8: [0.0015, 1.005]}

# %%
for x in X_train+X_test:
    for i in range(1,9):
        phi = (x[i]-scale_param[i][0])/(scale_param[i][1]-scale_param[i][0])
        x[i] = l+phi*(r-l)

# %%
scale_param = {}
for i in range(1,9):
    scale_param[i] = [X_train[0][i], X_train[0][i]]
for x in X_train:
    for i in range(1,9):
        if(x[i]<scale_param[i][0]):
            scale_param[i][0] = x[i]
        
        if(x[i]>scale_param[i][1]):
            scale_param[i][1] = x[i]
scale_param
# Out:
# {1: [-1.0, 1.0],
#  2: [-1.0, 1.0],
#  3: [-1.0, 1.0],
#  4: [-1.0, 1.0],
#  5: [-1.0, 1.0],
#  6: [-1.0, 1.0],
#  7: [-1.0, 1.0],
#  8: [-1.0, 1.0]}

# %% [markdown]
# 3. Consider binary classification that consists of distinguishing classes 1 through 9 from the rest...

# %%
# Splitting training data into 5 disjoint sets
import random
indices = list(range(len(X_train)))
random.shuffle(indices)
avgSize = int(len(indices)/5)

# %%
print (avgSize)
print (avgSize*5)
# Out:
# 626
# 3130

# %%
xSets = []
ySets = []
for i in range(5):
    xSet = []
    ySet = []
    for j in range(avgSize):
        xSet.append(X_train[indices[avgSize*i+j]])
        ySet.append(Y_train[indices[avgSize*i+j]])
    xSets.append(xSet)
    ySets.append(ySet)
# Out:
# [{1: 1.0, 2: 0.2702702702702704, 3: 0.26050420168067223, 4: -0.7345132743362832, 5: -0.4758278732070126, 6: -0.5272360457296571, 7: -0.5852534562211982, 8: -0.5884404583956153}, {1: 0.0, 2: 0.3378378378378377, 3: 0.24369747899159666, 4: -0.7699115044247787, 5: -0.44749424473171595, 6: -0.504371217215871, 7: -0.5418038183015143, 8: -0.6113602391629296}, {1: -1.0, 2: 0.44594594594594605, 3: 0.4285714285714286, 4: -0.7079646017699115, 5: -0.12024083584204004, 6: -0.14794889038332226, 7: -0.3245556287030942, 8: -0.3951170901843547}, {1: 0.0, 2: 0.4189189189189191, 3: 0.41176470588235303, 4: -0.7345132743362832, 5: -0.20099167699663545, 6: -0.22797579018157377, 7: -0.48518762343647137, 8: -0.3951170901843547}, {1: 0.0, 2: -0.1216216216216216, 3: -0.10924369747899154, 4: -0.8053097345132743, 5: -0.7513724101292723, 6: -0.812373907195696, 7: -0.7419354838709677, 8: -0.8036870951669157}, {1: -1.0, 2: 0.6081081081081083, 3: 0.6470588235294119, 4: -0.6460176991150441, 5: 0.20453338055604742, 6: 0.11903160726294537, 7: -0.016458196181698526, 8: -0.1858495266567015}, {1: 0.0, 2: 0.12162162162162149, 3: 0.008403361344537785, 4: -0.7168141592920354, 5: -0.3784310253231805, 6: -0.5326160053799598, 7: -0.43515470704410797, 8: -0.439960139511709}, {1: 1.0, 2: -0.06756756756756765, 3: -0.10924369747899154, 4: -0.7964601769911503, 5: -0.7350805737559767, 6: -0.7740416946872899, 7: -0.7590520078999342, 8: -0.8036870951669157}, {1: 1.0, 2: 0.027027027027026973, 3: -0.042016806722688926, 4: -0.7964601769911503, 5: -0.6571630954489109, 6: -0.6503026227303295, 7: -0.8288347597103358, 8: -0.7409068261086198}, {1: -1.0, 2: 0.6756756756756757, 3: 0.5798319327731094, 4: -0.6902654867256637, 5: 0.23251283867540273, 6: -0.06523201075991947, 7: 0.02304147465437789, 8: 0.0034877927254610697}, {1: 1.0, 2: 0.0, 3: -0.07563025210084018, 4: -0.8053097345132743, 5: -0.7478307065698602, 6: -0.7962340282447882, 7: -0.8248847926267281, 8: -0.7668161434977578}, {1: -1.0, 2: 0.45945945945945965, 3: 0.3613445378151261, 4: -0.6991150442477876, 5: -0.2530547193199929, 6: -0.35373234700739753, 7: -0.28505595786701776, 8: -0.46487294469357243}, {1: 1.0, 2: -0.5945945945945945, 3: -0.6302521008403361, 4: -0.9026548672566371, 5: -0.9596245794227023, 6: -0.9650302622730329, 7: -0.9684002633311389, 8: -0.9730941704035875}, {1: 1.0, 2: -0.5, 3: -0.5126050420168067, 4: -0.8761061946902655, 5: -0.9362493359305826, 6: -0.9515803631472765, 7: -0.9486504279131007, 8: -0.9431988041853513}, {1: -1.0, 2: 0.8783783783783785, 3: 0.8319327731092436, 4: -0.6194690265486725, 5: 0.553037010802196, 6: 0.41291190316072646, 7: 0.2679394338380512, 8: 0.16093672147483828}, {1: -1.0, 2: 0.21621621621621623, 3: 0.17647058823529438, 4: -0.7610619469026548, 5: -0.46484859217283514, 6: -0.5568258238063215, 7: -0.4325213956550362, 8: -0.6143497757847534}, {1: -1.0, 2: 0.5270270270270272, 3: 0.5294117647058825, 4: -0.6902654867256637, 5: -0.03240658756862047, 6: -0.308675184936113, 7: -0.30085582620144835, 8: 0.13303437967115106}, {1: -1.0, 2: 0.6756756756756757, 3: 0.6470588235294119, 4: -0.6725663716814159, 5: 0.11174074729945094, 6: -0.10759919300605258, 7: 0.008558262014483065, 8: -0.10513203786746372}, {1: 1.0, 2: 0.20270270270270263, 3: 0.14285714285714302, 4: -0.7610619469026548, 5: -0.5530370108021958, 6: -0.5998655010087425, 7: -0.6603028308097433, 8: -0.6542102640757349}, {1: 1.0, 2: 0.2702702702702704, 3: 0.17647058823529438, 4: -0.7610619469026548, 5: -0.5803081282096689, 6: -0.6381977135171486, 7: -0.6892692560895326, 8: -0.6342800199302441}, {1: -1.0, 2: 0.3378378378378377, 3: 0.32773109243697496, 4: -0.7522123893805309, 5: -0.43828581547724454, 6: -0.5460659045057161, 7: -0.6115865701119159, 8: -0.5146985550572993}, {1: -1.0, 2: 0.3918918918918919, 3: 0.3781512605042019, 4: -0.7522123893805309, 5: -0.26049229679475827, 6: -0.3698722259583054, 7: -0.3087557603686636, 8: -0.47882411559541593}, {1: 1.0, 2: 0.04054054054054057, 3: -0.05882352941176461, 4: -0.8053097345132743, 5: -0.6869134053 ...

# %%
from matplotlib import pyplot as plt
import math

# %%
def cross_validate(d):
    Cs = []
    errors = []
    sigmas = []
    k = 5
    mss = []
    
    for j in range(-k, k+7):
        C = 3**j
        errorSum = 0;
        sqSum = 0
        ms = []
        for n in range(5):
            testX, trainX, testY, trainY = merge_data(n)
            prob = svm_problem(trainY, trainX)
            param = svm_parameter('-t 1 -c '+str(C)+' -d '+str(d))
            print('-t 1 -c '+str(C)+' -d '+str(d))
            m = svm_train(prob, param)
            # save model to prevent loss
            svm_save_model(str(d)+','+str(j)+','+str(n)+'.model', m)
            ms.append(m)
            labels, acc, vals = svm_predict(testY, testX, m)
            errorSum+=1-acc[0]/100
            sqSum+=(1-acc[0]/100)**2
        Cs.append(C)
        mean = errorSum/5
        errors.append(mean)
        sigmas.append(math.sqrt((sqSum-5*(mean**2))/4))
        print("avg error: "+str(errorSum/5))
        print("std: "+str(math.sqrt((sqSum-5*(mean**2))/4)))
        mss.append(ms)
    return Cs, errors, sigmas, mss
        
# Remerge data for cross validation
def merge_data(n):
    trainX = []
    testX = xSets[n]
    trainY = []
    testY = ySets[n]
    for i in range(5):
        if(i!=n):
            trainX+=xSets[i]
            trainY+=ySets[i]
    return testX, trainX, testY, trainY

# %%
Css = []
errorss = []
sigmass = []
msss = []
for d in range(1, 6):
    Cs, errors, sigmas, mss = cross_validate(d)
    Css.append(Cs)
    errorss.append(errors)
    sigmass.append(sigmas)
    msss.append(mss)
# Out:
# -t 1 -c 0.00411522633744856 -d 1
# Accuracy = 18.2109% (114/626) (classification)
# -t 1 -c 0.00411522633744856 -d 1
# Accuracy = 14.6965% (92/626) (classification)
# -t 1 -c 0.00411522633744856 -d 1
# Accuracy = 16.9329% (106/626) (classification)
# -t 1 -c 0.00411522633744856 -d 1
# Accuracy = 15.016% (94/626) (classification)
# -t 1 -c 0.00411522633744856 -d 1
# Accuracy = 18.6901% (117/626) (classification)
# avg error: 0.8329073482428117
# std: 0.018129406976483152
# -t 1 -c 0.012345679012345678 -d 1
# Accuracy = 18.2109% (114/626) (classification)
# -t 1 -c 0.012345679012345678 -d 1
# Accuracy = 14.6965% (92/626) (classification)
# -t 1 -c 0.012345679012345678 -d 1
# Accuracy = 16.9329% (106/626) (classification)
# -t 1 -c 0.012345679012345678 -d 1
# Accuracy = 15.016% (94/626) (classification)
# -t 1 -c 0.012345679012345678 -d 1
# Accuracy = 18.6901% (117/626) (classification)
# avg error: 0.8329073482428117
# std: 0.018129406976483152
# -t 1 -c 0.037037037037037035 -d 1
# Accuracy = 18.3706% (115/626) (classification)
# -t 1 -c 0.037037037037037035 -d 1
# Accuracy = 14.6965% (92/626) (classification)
# -t 1 -c 0.037037037037037035 -d 1
# Accuracy = 19.9681% (125/626) (classification)
# -t 1 -c 0.037037037037037035 -d 1
# Accuracy = 17.4121% (109/626) (classification)
# -t 1 -c 0.037037037037037035 -d 1
# Accuracy = 20.1278% (126/626) (classification)
# avg error: 0.8188498402555912
# std: 0.02220964382291744
# -t 1 -c 0.1111111111111111 -d 1
# Accuracy = 19.9681% (125/626) (classification)
# -t 1 -c 0.1111111111111111 -d 1
# Accuracy = 20.4473% (128/626) (classification)
# -t 1 -c 0.1111111111111111 -d 1
# Accuracy = 23.1629% (145/626) (classification)
# -t 1 -c 0.1111111111111111 -d 1
# Accuracy = 21.0863% (132/626) (classification)
# -t 1 -c 0.1111111111111111 -d 1
# Accuracy = 19.9681% (125/626) (classification)
# avg error: 0.7907348242811503
# std: 0.013317357827898783
# -t 1 -c 0.3333333333333333 -d 1
# Accuracy = 22.6837% (142/626) (classification)
# -t 1 -c 0.3333333333333333 -d 1
# Accuracy = 25.7188% (161/626) (classification)
# -t 1 -c 0.3333333333333333 -d 1
# Accuracy = 23.9617% (150/626) (classification)
# -t 1 -c 0.3333333333333333 -d 1
# Accuracy = 23.8019% (149/626) (classification)
# -t 1 -c 0.3333333333333333 -d 1
# Accuracy = 20.9265% (131/626) (classification)
# avg error: 0.765814696485623
# std: 0.017666027221662373
# -t 1 -c 1 -d 1
# Accuracy = 23.9617% (150/626) (classification)
# -t 1 -c 1 -d 1
# Accuracy = 26.5176% (166/626) (classification)
# -t 1 -c 1 -d 1
# Accuracy = 25.0799% (157/626) (classification)
# -t 1 -c 1 -d 1
# Accuracy = 23.0032% (144/626) (classification)
# -t 1 -c 1 -d 1
# Accuracy = 21.4058% (134/626) (classification)
# avg error: 0.7600638977635782
# std: 0.019512372504285835
# -t 1 -c 3 -d 1
# Accuracy = 27.476% (172/626) (classification)
# -t 1 -c 3 -d 1
# Accuracy = 26.9968% (169/626) (classification)
# -t 1 -c 3 -d 1
# Accuracy = 25.8786% (162/626) (classification)
# -t 1 -c 3 -d 1
# Accuracy = 23.9617% (150/626) (classification)
# -t 1 -c 3 -d 1
# Accuracy = 22.3642% (140/626) (classification)
# avg error: 0.7466453674121405
# std: 0.021420051491198414
# -t 1 -c 9 -d 1
# Accuracy = 26.9968% (169/626) (classification)
# -t 1 -c 9 -d 1
# Accuracy = 27.476% (172/626) (classification)
# -t 1 -c 9 -d 1
# Accuracy = 25.7188% (161/626) (classification)
# -t 1 -c 9 -d 1
# Accuracy = 23.6422% (148/626) (classification)
# -t 1 -c 9 -d 1
# Accuracy = 24.1214% (151/626) (classification)
# avg error: 0.7440894568690096
# std: 0.016958507382863263
# -t 1 -c 27 -d 1
# Accuracy = 27.1565% (170/626) (classification)
# -t 1 -c 27 -d 1
# Accuracy = 28.115% (176/626) (classification)
# -t 1 -c 27 -d 1
# Accuracy = 25.7188% (161/626) (classification)
# -t 1 -c 27 -d 1
# Accuracy = 24.1214% (151/626) (classification)
# -t 1 -c 27 -d 1
# Accuracy = 23.3227% (146/626) (classification)
# avg error: 0.7431309904153356
# std: 0.020060488914948313
# -t 1 -c 81 -d 1
# Accuracy = 28.5942% (179/626) (classification)
# -t 1 -c 81 -d 1
# Accuracy = 28.4345% (178/626) (classification)
# -t 1 -c 81 -d 1
# Accuracy = 27.3163% (171/626) (classification)
# -t 1 -c 81 -d 1
# Accuracy = 24.2812% (152/626) (classification)
# -t 1 -c 81 -d 1
# Accuracy = 23.6422% (148/626) (classification)
# avg error: 0.7354632587859424
# std: 0.023384966511395804
# -t 1 -c 243 -d 1
# Accuracy = 28.2748% (177/626) (classification)
# -t 1 -c 243 -d 1
# Accuracy = 27.6358% (173/626) (classification)
# -t 1 -c 243 -d 1
# Accuracy = 27.9553% (175/626) (classification)
# -t 1 -c 243 -d 1
# Accuracy = 23.8019% (149/626) (classification)
# -t 1 -c 243 -d 1
# Accuracy = 23.8019% (149/626) (classification)
# avg error: 0.7370607028753994
# std: 0.02286075887539419
# -t 1 -c 729 -d 1
# Accuracy = 27.7955% (174/626) (classification)
# -t 1 -c 729 -d 1
# Accuracy = 27.3163% (171/626) (classification)
# -t 1 -c 729 -d 1
# Accuracy = 27.9553% (175/626) (classification)
# -t 1 -c 729 -d 1
# Accuracy = 23.6422% (148/626) (classification)
# -t 1 -c 729 -d 1
# Accuracy = 23.4824% (147/626) (classification)
# avg error: 0.7396166134185304
# std: 0.02273202790855893
# -t 1 -c 2187 -d 1
# Accuracy = 28.2748% (177/626) (classification)
# -t 1 -c 2187 -d 1
# Accuracy = 26.6773% (167/626) (classification)
# -t 1 -c 2187 -d 1
# Accuracy = 27.3163% (171/626) (classification)
# -t 1 -c 2187 -d 1
# Accuracy = 23.4824% (147/626) (classification)
# -t 1 -c 2187 -d 1
# Accuracy = 23.8019% (149/626) (classification)
# avg error: 0.7408945686900958
# std: 0.021503282645960013
# -t 1 -c 6561 -d 1
# Accuracy = 28.4345% (178/626) (classification)
# -t 1 -c 6561 -d 1
# Accuracy = 26.5176% (166/626) (classification)
# -t 1 -c 6561 -d 1

# %%
for i in range(5):
    plt.plot([math.log(x,3) for x in Cs],errorss[i], label = "d = "+str(i+1))
    

    plt.legend()

# %% [markdown]
# 4. Let (C∗, d∗) be the best pair found previously. Fix C to be C∗. Plot the five-fold cross-validation error and the test errors for the hypotheses obtained as a function of d. Plot the average number of support vectors obtained as a function of d. How many of the support vectors lie on the margin hyperplanes?
